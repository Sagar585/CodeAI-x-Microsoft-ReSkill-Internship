# %%
import pandas as pd

# Load the dataset
books_df = pd.read_csv('books.csv')

def search_books(keyword):
    """
    Search for books that match the keyword in the title, authors, or publisher.
    """
    keyword = keyword.lower()
    results = books_df[
        books_df['title'].str.lower().str.contains(keyword) |
        books_df['authors'].str.lower().str.contains(keyword) |
        books_df['publisher'].str.lower().str.contains(keyword)
    ]
    return results


def display_books(books):
    """
    Display the list of books.
    """
    if books.empty:
        print("No books found.")
    else:
        for index, book in books.iterrows():
            print(f"Title: {book['title']}")
            print(f"Author: {book['authors']}")
            print(f"Average Rating: {book['average_rating']}")
            print(f"ISBN: {book['isbn']}")
            print(f"ISBN13: {book['isbn13']}")
            print(f"Language: {book['language_code']}")
            # Check if 'num_pages' column exists before printing
            if 'num_pages' in book:
                print(f"Number of Pages: {book['num_pages']}")
            print(f"Ratings Count: {book['ratings_count']}")
            print(f"Text Reviews Count: {book['text_reviews_count']}")
            print(f"Publication Date: {book['publication_date']}")
            print(f"Publisher: {book['publisher']}")
            print('-' * 40)

def main():
    print("Welcome to the Book Recommendation Program!")
    keyword = input("Enter a keyword to search for books: ")
    results = search_books(keyword)
    display_books(results)

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Book Recommendation Program!
# Title: Cat Breaking Free (Joe Grey  #11)
# Author: Shirley Rousseau Murphy
# Average Rating: 4.22
# ISBN: 60578122
# ISBN13: 9.78006E+12
# Language: eng
# Ratings Count: 225
# Text Reviews Count: 20
# Publication Date: 10-01-2006
# Publisher: Avon
# ----------------------------------------
# Title: Cat Cross Their Graves (Joe Grey  #10)
# Author: Shirley Rousseau Murphy
# Average Rating: 4.32
# ISBN: 60578114
# ISBN13: 9.78006E+12
# Language: eng
# Ratings Count: 504
# Text Reviews Count: 28
# Publication Date: 9/27/2005
# Publisher: Avon
# ----------------------------------------
# Title: Cat in the Dark (Joe Grey  #4)
# Author: Shirley Rousseau Murphy
# Average Rating: 4.25
# ISBN: 61059471
# ISBN13: 9.78006E+12
# Language: en-US
# Ratings Count: 723
# Text Reviews Count: 36
# Publication Date: 11-03-1999
# Publisher: Avon
# ----------------------------------------
# Title: Winter Moon (Walker Papers  #1.5)
# Author: Mercedes Lackey/Tanith Lee/C.E. Murphy
# Average Rating: 3.78
# ISBN: 373802390
# ISBN13: 9.78037E+12
# Language: eng
# Ratings Count: 2668
# Text Reviews Count: 148
# Publication Date: 10/25/2005
# Publisher: Luna Books
# ----------------------------------------
# Title: The Lord of the Rings
# Author: J.R.R. Tolkien/Brian Sibley/Michael Bakewell/Stephen  Oliver/Ian Holm/Michael Hordern/Robert Stephens/John Le Mesurier/Peter Woodthorpe/Gerard  Murphy/Hugh Dickson/Peter Vaughan/Peter Howell
# Average Rating: 4.5
# ISBN: 563494859
# ISBN13: 9.78056E+12
# Language: eng
# Ratings Count: 2
# Text Reviews Count: 0
# Publication Date: 10-06-2003
# Publisher: BBC Audiobooks
# ----------------------------------------
# Title: Father to Son  (The Destroyer  #129)
# Author: Warren Murphy/Richard Sapir/James Mullaney
# Average Rating: 4.11
# ISBN: 373632444
# ISBN13: 9.78037E+12
# Language: eng
# Ratings Count: 60
# Text Reviews Count: 4
# Publication Date: 10-01-2002
# Publisher: Gold Eagle
# ----------------------------------------
# Title: Drum Into Silence (Drums of Chaos  #3)
# Author: Jo Clayton/Kevin Andrew Murphy
# Average Rating: 3.41
# ISBN: 812551249
# ISBN13: 9.78081E+12
# Language: en-GB
# Ratings Count: 1
# Text Reviews Count: 0
# Publication Date: 02-01-2004
# Publisher: Tor Fantasy
# ----------------------------------------
# Title: The Best Bug Parade
# Author: Stuart J. Murphy/Holly Keller
# Average Rating: 3.51
# ISBN: 64467007
# ISBN13: 9.78006E+12
# Language: en-US
# Ratings Count: 85
# Text Reviews Count: 16
# Publication Date: 3/27/1996
# Publisher: HarperCollins
# ----------------------------------------
# Title: Thunderbird Falls  (Walker Papers  #2)
# Author: C.E. Murphy
# Average Rating: 3.85
# ISBN: 373802358
# ISBN13: 9.78037E+12
# Language: eng
# Ratings Count: 5729
# Text Reviews Count: 256
# Publication Date: 4/25/2006
# Publisher: Luna Books
# ----------------------------------------
# Title: Coyote Dreams (Walker Papers  #3)
# Author: C.E. Murphy
# Average Rating: 4
# ISBN: 373802722
# ISBN13: 9.78037E+12
# Language: eng
# Ratings Count: 5810
# Text Reviews Count: 200
# Publication Date: 4/24/2007
# Publisher: Luna Books
# ----------------------------------------
# Title: The Philosophy of Antonio Negri  Volume One: Resistance in Practice
# Author: Timothy S. Murphy/Abdul-Karim Mustapha
# Average Rating: 4.12
# ISBN: 745323375
# ISBN13: 9.78075E+12
# Language: eng
# Ratings Count: 8
# Text Reviews Count: 1
# Publication Date: 7/20/2005
# Publisher: Pluto Press
# ----------------------------------------
# Title: The Catswold Portal
# Author: Shirley Rousseau Murphy
# Average Rating: 4.06
# ISBN: 60765402
# ISBN13: 9.78006E+12
# Language: eng
# Ratings Count: 888
# Text Reviews Count: 69
# Publication Date: 1/25/2005
# Publisher: Harper Voyager
# ----------------------------------------
# Title: Cat Laughing Last (Joe Grey  #7)
# Author: Shirley Rousseau Murphy
# Average Rating: 4.22
# ISBN: 61015628
# ISBN13: 9.78006E+12
# Language: eng
# Ratings Count: 654
# Text Reviews Count: 43
# Publication Date: 11-05-2002
# Publisher: Avon
# ----------------------------------------
# Title: Cat Seeing Double (Joe Grey  #8)
# Author: Shirley Rousseau Murphy
# Average Rating: 4.25
# ISBN: 006101561X
# ISBN13: 9.78006E+12
# Language: eng
# Ratings Count: 582
# Text Reviews Count: 22
# Publication Date: 10/28/2003
# Publisher: Avon
# ----------------------------------------
# Title: Fergus and the Night-Demon
# Author: Jim  Murphy/John Manders
# Average Rating: 3.69
# ISBN: 618339558
# ISBN13: 9.78062E+12
# Language: en-US
# Ratings Count: 81
# Text Reviews Count: 18
# Publication Date: 9/18/2006
# Publisher: Clarion Books
# ----------------------------------------
# Title: The Legend of Spud Murphy
# Author: Eoin Colfer/Glenn McCoy
# Average Rating: 3.88
# ISBN: 786855010
# ISBN13: 9.78079E+12
# Language: eng
# Ratings Count: 92
# Text Reviews Count: 25
# Publication Date: 09-06-2004
# Publisher: Disney-Hyperion
# ----------------------------------------
